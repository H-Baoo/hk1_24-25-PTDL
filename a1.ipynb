# %%
import pandas as pd
df=pd.read_csv('company_info.csv')
df
# Out:
#          Số ĐKKD/MST                                        Tên công ty  \
# 0         1102072453                         CÔNG TY TNHH BĐS BLUELANDS
# 1     0317747520-001  CÔNG TY TNHH TƯ VẤN LUẬT GIA BẢO - CHI NHÁNH B...
# 2         1102072083   CÔNG TY TNHH ĐT XÂY DỰNG THƯƠNG MẠI K.L.M VÕ GIA
# 3         1102072090               CÔNG TY TNHH MÔI TRƯỜNG VÀ NÔNG DƯỢC
# 4         1102072164       CÔNG TY TNHH ĐẦU TƯ THƯƠNG MẠI DỊCH MỘC XANH
# ...              ...                                                ...
# 1464  0316569152-001  CHI NHÁNH I- CÔNG TY TNHH THƯƠNG MẠI DỊCH VỤ A...
# 1465      1101967839  CÔNG TY TNHH MTV CUNG CẤP SUẤT ĂN CÔNG NGHIỆP ...
# 1466      1101967564    CÔNG TY TNHH THƯƠNG MẠI XUẤT NHẬP KHẨU KIÊN HAN
# 1467  0105863010-001  CHI NHÁNH CÔNG TY CỔ PHẦN DỊCH VỤ VÀ TỰ ĐỘNG H...
# 1468  0316266768-001  CHI NHÁNH CÔNG TY TNHH SẢN XUẤT - THƯƠNG MẠI -...
#
#                                                 Địa chỉ Ngày thành lập  \
# ...
